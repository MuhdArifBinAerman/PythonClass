# %% [markdown]
# # <h1>**Inputs and Outputs**</h1>

# %% [markdown]
# ## <h2>We have just learnt how to use the `print` function to output a message.</h2>
#
#
# Have you wondered how do we ask for an input from the user? 🤔
#
#
# Getting an input from the user allows us to make more flexible choices. We will cover more about that in the later labs.

# %%
# By using input(), we can prompt the user to enter some information we want from them
# Below is a simple input code, try uncomment it and run the cell

# input()
# Out:
# Hello
# 'Hello'

# %% [markdown]
# ## <h2> Storing of input in a variable

# %% [markdown]
# If you notice the output from the last cell, we cannot find it back as we have no idea where it is stored. 🤓❓
#
#
# " **Variable** " is what we used to store a data ( You will see them frequently💡)

# %%
# The expression on the left-hand side (LHS) is called a variable. We will learn more about it later on in the labs.
# Uncomment the following lines 

# answer = input("What is your name: ") # Save the inputted name to the variable answer
# print(answer) # Output answer
# Out:
# What is your name: David
# David

# %% [markdown]
# <h5>Notice that if we do not enter a name when prompted, the variable answer is not outputted. </h5>

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# <br />
#
# Try to prompt user to enter his/her age then print the output.
#
# ---
#
# Expected output:
# ```
# Please enter your age: 10
# Your age is 10.
# ```
#
# ---

# %%
# Your code

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# <br />
#
# Now let's try to get two numbers from the user.
#
# Then, we add them together.
#
# ---
#
# Expected output:
#
# ```
# Please enter the first num: 10
#
# Please enter the second num: 12
#
# Total number is 22
# ```
#
# ---

# %%
# Your code
