# %% [markdown]
# <h1>Conditional Statements

# %% [markdown]
# Conditions allows the user to carry out different actions when different condition is met. 🔃
#
# Here are some examples:
# * Equal to: a == b
# * Not Equal to: a != b
# * Less than: a < b
# * Less than or equal to: a <= b
# * Greater than: a > b
# * Greater than or equal to: a >= b

# %% [markdown]
# # " If " Statement

# %% [markdown]
# ### Keyword `if`

# %% [markdown]
# An " if " statement is constructed using the keyword `if`
#
#
#
#
# Here is a formula for you 🔣:
# ```
# if (condition is met):
#   (action taken)
# ```

# %%
# Uncomment the following lines to see the output.

# a = 10
# b = 10

# if (a == b):
#   print("a is equal to b")
# Out:
# a is equal to b

# %% [markdown]
# You can change the condition to meet your requirements.

# %%
# Uncomment the following lines to see the output

# a = 20
# b = 10

# if (a > b):
#   print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ## Indentation

# %% [markdown]
# Take note that Python relies on **indentation** ( space in the beginning of the code ) to define a scope.
#
# **Indentation** can be inserted by adding " **4 spaces** " or simply use " **Tab** "

# %%
# Without indentation in an "if" statement, an error will be raised
# Uncomment the following lines to see the output. (You will get an error [Try resolve it by adding indentation])

a = 20
b = 10

if (a > b):
print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ## Keyword `elif`

# %% [markdown]
# Keyword `elif` is usually placed after `if`.
#
# Meaning that check this ( `elif` ) if the statement above ( `if` ) is wrong.

# %%
# Please take note of the indentation
# Uncomment the following lines to see the output

a = 10
b = 10

if (a > b):
  print("a is greater than b")

elif (a == b):
  print("a is equal to b")
# Out:
# a is equal to b

# %% [markdown]
# Condition for `if` will be check first before going to `elif`.

# %%
a = 10
b = 10

if (a == b):
  print("a is equal than b")

elif (a > b):
  print("a is greater to b")
# Out:
# a is equal than b

# %% [markdown]
# ## Keyword `else`

# %% [markdown]
# `else` allows you to give action when none of the conditions is met

# %%
# Uncomment the following lines to see the output

a = 10
b = 10

if (a > b):
  print(" a is greater than b ")
else:
  print(" no condition is met ")
# Out:
#  no condition is met

# %% [markdown]
# You can add an `elif` in between.

# %%
# Uncomment the following lines to see the output

a = 10
b = 10

if (a > b):
  print("a is greater than b")
elif (a < b):
  print("a is smaller than b")
else:
  print("no condition is met")
# Out:
# no condition is met

# %% [markdown]
# And not only 1 `elif` if you wish to use more.

# %%
# Uncomment the following lines to see the output

a = 10
b = 10

if (a > b):
  print("a is greater than b")
elif (a < b):
  print("a is smaller than b")
elif (a == 20):
  print("a is 20")
elif (b == 30):
  print("b is 30")
else:
  print("no condition is met")
# Out:
# no condition is met

# %% [markdown]
# As mentioned earlier, `if`, `elif` and `else` statement are checked accoridingly from `if` to `else`.
#
# Once a condition is met, the following conditions will not be checked.

# %%
# Uncomment the following lines to see the output

a = 10
b = 10

if (a == 10):
  print("a is equal to 10")
elif (b == 10):
  print("b is equal to 10")
elif (a == b):
  print("a is equal to b")
else:
  print("no condition is met")
# Out:
# a is equal to 10

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# <br />
#
# Write a programme to check if a user is underweight, acceptable or overweight from his BMI by:<br>
# (a) Asking the user to enter his weight and height from keyboard<br>
# (b) Computing the BMI<br>
# (c) Using `if`, `elif` and `else` statements to check if the user is underweight (BMI less than 18), acceptable (BMI between 18 to 25) or overweight (BMI above 25)

# %%
# Uncomment and modify the code below to attempt Exercise 1

# bmi = height = weight = 0.0 #Initialize Variables to 0.0

# height = float(input("Enter your height in (m) : ")) #Ask user to enter height and convert it to float

# weight = #Ask user to enter weight and convert it to float

# bmi = #Calculate BMI using weight/(height*height)

# print("Your BMI is:", bmi) #Display user's BMI

# if ():
#   print("")
# elif ():
#   print("")
# else:
#   print("")

# %% [markdown]
# ##Exercise 2

# %% [markdown]
# <br />
#
# Create a programme that check whether a user is able to buy the item he/she wanted or not.
#
# (a) Ask user to enter the money he/she have.
#
# (b) Ask user to enter the price of the item he/she wants to buy.
#
# (c) If the money they owned is greater than the price, `print` " Yes, you can buy it. "
#
# (d) If the price is greater than the money owned, `print` " Sorry, you don't have enough money for that. "
#
# (e) If both money owned and the price are the same, `print` " Just nice, you have the exact amount of money for this item. "

# %%
# You can refer to Exercise 1 to modify it for this question
# (your code)

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# <br />
#
# Create a programme that performs simple calculation.
#
# (a) Ask user for the first number.
#
# (b) Ask user for the second number.
#
# (c) Ask user for the operations he/she wish to perform. ( + , - , / , *)
# - " / " for division and " * " for multiplication
#
# (d) Display the result.

# %%
# Uncomment the following lines and modify the code

# first_num = 
# second_num = 
# operation = input("Please choose one operation (+,-,/,*): ")

# if (operation == "+"):
  # perform addition on first_num and second_num

# elif (operation == "-"):
  # perform substraction on first_num and second_num

# elif (operation == "*"):
  # perform multiplication on first_num and second_num

# complete the division part (you can refer to the code above)

# else:
  # print("Invalid selection.")
