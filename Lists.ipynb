# %% [markdown]
# <h1>Lists</h1>
# Lists can be used to store multiple items of any data type in a single variable.

# %%
# Uncomment the code below to see how it works

# intList = [5, 4, 3, 1, 5]
# strList = ["Orange", "Apple", "Grape"]
# mixList = ["James", 5, 3.0, True, False]
# print(intList, strList, mixList, sep="\n")

# %% [markdown]
# <h1>List Index</h1>
# The items in a list are indexed, with the first item having index 0, the second item having index 1, etc.<br>
# The indexing operator [ ] can be used to select a single element from a list.

# %%
# Uncomment the code below to see how it works

# location = ["Bedok", "Changi", "Jurong"]

# print("Index 0 in the location variable is", location[0])

# %% [markdown]
# <h1>List Length</h1>
# To determine the number of items in a list, the len() function can be used.

# %%
# Uncomment the code below to see how it works

# color = ["red", "green", "blue", "yellow", "brown"]

# print("The length of the color list is", len(color))

# %% [markdown]
# <h1>Exercise 1</h1>
# Write a programme to loop through and display every element in a list by using a for loop, the range() function, the len() function, and the indexing operator [ ].

# %%
# Uncomment and modify the ??? in the code below to attempt Exercise 1

# days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# for i in range(???):
#   print(???)

# %% [markdown]
# <h1>List Slicing</h1>
# List slicing [ : ] can be used to return a section of a list.

# %%
# Uncomment the code below to see how it works

# fruit = ["Kiwi", "Apple", "Banana", "Cherry", "Orange", "Blueberry", "Watermelon"]

# print(fruit[2:5]) #Returns a list with items from index 2 to index 4

# %% [markdown]
# <h1>Adding Items to a List</h1>
# 1. The append() method can be used to add an item to the end of a list.<br>
# 2. The extend() method can be used to add all items in one list to another.<br>
# 3. The insert() method can be used to add an item at the specified index.

# %%
# Uncomment the code below to see how it works

# num = [5, 6, 11, 15]
# evenNum = [2, 6, 12, 20]

# print("Before Append:", num)
# num.append(4)
# print("After Append:", num)

# print("Before Extend:", num)
# num.extend(evenNum)
# print("After Extend:", num)

# print("Before Insert:", num)
# num.insert(2, 3) #Insert 3 at index 2
# print("After Insert:", num)

# %% [markdown]
# <h1>Removing Items From a List</h1>
# 1. The del statement can be used to remove one or more items from a list.<br>
# 2. The remove() method can be used to delete a specified list item.<br>
# 3. The pop() method can be used to remove the item at the specified index and return the removed item.

# %%
# Uncomment the code below to see how it works

# names = ["James", "Sam", "Sarah", "Joshua", "Timothy", "Daniel"]

# print("Before 1st Del", names)
# del names[1] #Delete the second item
# print("After 1st Del", names)

# print("Before 2nd Del", names)
# del names[2:4] #Delete the third and fourth item
# print("After 2nd Del", names)

# print("Before remove", names)
# names.remove("Sarah") #Remove "Sarah from the list"
# print("After remove", names)

# print("Before pop", names)
# removedName = names.pop(1) #Remove the second item and save it to the variable removedName
# print("After removing the item", removedName, "the updated list is", names)

# %% [markdown]
# <h1>Updating Item in a List</h1>
# Python lists are mutable (changeable).<br>
# The items in a list can be changed by assigning new values using the = operator.

# %%
# Uncomment the code below to see how it works

# marks = [99, 75, 68, 89, 50, 35, 67]

# print("Before changing", marks)
# marks[3] = 65 #Changing the fourth item to 65
# print("After changing", marks)

# %% [markdown]
# <h1>List Comprehension</h1>
# List comprehension is a concise and elegant way to create lists.<br>
# A list comprehension consists of an expression followed by the for statement inside square brackets.

# %%
# Uncomment the code below to see how it works

# numbers = [number for number in range(10)] #Create a list with numbers from 0 to 9

# print(numbers) #Display the created list

# %% [markdown]
# <h1>Exercise 2</h1>
# Write a programme to display the squared numbers in the range specified by the user using list comprehension.

# %%
# Uncomment and modify the ??? in the code below to attempt Exercise 2

# lRange = int(input("Enter the lower range: ")) #Ask user to enter the start range
# uRange = ??? #Ask user to enter the end range

# squaredList = [???] #Use list comprehension to create the squared numbers in the range specified by the user

# print("The squared numbers in the given range of", lRange, "to", uRange, "is", squaredList) #Display the squared numbers

# %% [markdown]
# <h1>Multi-dimensional Lists</h1>
# There can be more than one dimension in a list. Since a list can hold other lists, the application of this principle allows for multi-dimensional lists (lists within lists).

# %% [markdown]
# <h1>2-Dimensional (2D) Lists</h1>
# So far, we have looked into how 1-Dimensional Arrays work. In our daily work, we will often encounter data stored in the form of a table. Such data can be represented in the form of 2D Lists. We will now look into how to create, modify and display data in the form of 2D lists.

# %% [markdown]
# <h1>Initializing/Creating 2D Lists</h1>
# Recall the List Comprehension concept learned in the creation of 1D Lists. The same concept can also be applied to create 2D Lists. Try the example below to see how 2D Lists can be created using List Comprehension.

# %%
# Uncomment the code below to see how it works
# rows = 5 #Number of Rows
# cols = 4 #Number of Columns

# list_2d = [[0 for x in range(cols)] for x in range(rows)] #Initialize a 2D List with 5 rows and 4 columns containing zeros

# print(list_2d) #Display the 2D List

# %% [markdown]
# <h1>Modifying and Displaying Data in 2D Lists</h1>
# Try the example below to see how to modify and display data in a 2D List

# %%
# Uncomment the code below to see how it works
# rows = 3 #Number of Rows
# cols = 2 #Number of Columns

# marks = [[0 for x in range(cols)] for x in range(rows)] #Initialize a 2D List to store the marks of 2 subjects for 3 students

# for c in range(len(marks)):
  # print(str(c+1) + "st", "Student", "Marks")
  # marks[c][0] = int(input("Enter Math Mark: ")) #Ask user to enter Math marks
  # marks[c][1] = int(input("Enter Science Marks: ")) #Ask user to enter Science marks

# for s in range(len(marks)):
  # print("The", str(s+1) + "st", "Student scored", marks[s][0], "Marks in Math and", marks[s][1], "Marks in Science.") #Display Math and Science Marks for all students

# %% [markdown]
# <h1>Exercise 3</h1>
# Using the above example as a guide, write a programme to ask the user for 7 days (Monday to Sunday) of temperature data in 3 cities and output the data in the format City [Number]: [Temperature Data seperated by comma].

# %%
# Uncomment and modify the ??? in the code below to attempt Exercise 3
# rows = ??? #Number of Rows
# cols = ??? #Number of Columns

# tempData = ??? #Intialize your 2D List

# for c in range(???):
#   print("City", c + 1, "Temperature")
#   tempData[c][0] = float(input("Enter Monday's Temperature: ")) #Ask user to enter Monday's Temperature
#   tempData[c][1] = ??? #Ask user to enter Tuesday's Temperature
#   tempData[c][2] = ??? #Ask user to enter Wednesday's Temperature
#   tempData[c][3] = ??? #Ask user to enter Thursday's Temperature
#   tempData[c][4] = ??? #Ask user to enter Friday's Temperature
#   tempData[c][5] = ??? #Ask user to enter Saturday's Temperature
#   tempData[c][6] = ??? #Ask user to enter Sunday's Temperature

# for r in range(???):
#   print("City", r+1, "temperature data from Monday to Sunday are", ???) #Display the 7 temperature data seperated by commas for all cities
