# %% [markdown]
# # Variable and Scope

# %% [markdown]
# ## Introduction to Variables

# %% [markdown]
# In this lab, we will look at " **Variables** " (shown in the previous lab).
#
# <hr />
# <h3>What is a variable❓</h3>
#
# <h5>Variable is used to hold a value (word or number).</h5>
#
# <h5> Think it as a box. Item we put in it is the value.
#
# <hr />
# <h5>Another focus of this lab is to also introduce the diffferent data types and arithmetic operations in Python.
#
# Without further ado, let's get started 💪</h5>

# %%
#Remember names you put at the left hand side (LHS) are called variables

age = 30

print(age) #output 30
# Out:
# 30

# %% [markdown]
# ## Naming Rule for Variables

# %% [markdown]
# <h4>There is something called variable naming convention in Python. It determines which name is allowed in Python. The below are the rules one needs to remember when creating a variable. 📓</h4>
#
# *  A variable name must start with a letter or the underscore character
# *  A variable name cannot start with a number
# *  A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# *  Variable names are case-sensitive (age, Age and AGE are three different variables)
# <h5>Credits: <a href="https://www.w3schools.com/python/gloss_python_variable_names.asp">w3schools</a>
# </h5>

# %%
#Credits: https://www.w3schools.com/python/gloss_python_variable_names.asp

# Legal variable names:
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# Illegal variable names:

# Uncomment them out to see the errors
# 2myvar = "John"
# my-var = "John"
# my var = "John"

# %% [markdown]
# ## Scope

# %% [markdown]
# When your variable is only available in a region created. It's a scope. 🗺
#
# Scope helps to decide where you can use your variable.
# <hr />
#
# You might notice some unfamiliar keywords here but don't worry, you will learn that when you reach deeper.
#
# Try focus on the variable. Its our main character 👑 for this session.
# <hr />

# %% [markdown]
# <h3>Global Scope</h3>
#
# As the name implies, you can use it anywhere.

# %%
# Uncomment the code below to see the output.

# x = 10

# def my_function():   # this is a region you created which is known as "functions"
#   print(x)          # you can let it carry out some actions

# my_function()       # we can call it to let it do the action you gave
# print(x)
# Out:
# 10
# 10

# %% [markdown]
# <h3>Local Scope</h3>
#
# Your variable only works in a certain region.

# %%
# Observe the value our variable " x " is holding
# Uncomment the code below to see the output.

x = 10

def my_function():  
  x = 20            # this variable only can be used inside here 
  print(x)          

print(x)
my_function()
# Out:
# 10
# 20

# %% [markdown]
# ## Data Types

# %% [markdown]
# <h4>Before we continue, let us show you the common data types Python have.</h4>
#
#
# * In the previous code, 30 is a number. We call that as an **integer** in Python.
#
#
# * " Hello World " is a **string**. A **string** is defined when you enclose double quotation or single quotation marks for a word, phrase or sentence.
#
#
# * In the case of 1.0101, the data type to store such value is called **float**. Usually, **float** is the data type for decimals.

# %%
# Data Types
 
# The type function in this example tells you the data type of a right-hand side (RHS) value
# RHS refers to values that will be stored be in a variable

# LHS = RHS

# Uncomment the following lines one by one to see its data type.

# print(type(30))
# print(type("Hello World")) #str means string
# print(type(1.0101))

# %% [markdown]
# *italicised text*## Arithmetic Operation

# %% [markdown]
# The section below will show you how to perform basic arithmetic operation such as:
# * addition ( + )
# * multiplication ( * )
# * division ( / )
# * substraction ( - )
#
# These 4 operations are used very commonly in Python.
#
# It is very straightforward and easy.

# %%
# Uncomment the code for one of the subsections to see the correct output

# Addition
# age = 10 + 5 #gives 15

# Substraction 
# age = 10 - 5 #gives 5

# Divison
# age = 10 / 5 #gives 2.0 because any division will return a float data type

# Multipication
# age = 10 * 5

print(age)

# %% [markdown]
# Other than using the 4 basic arithmetic operations, we also use operations to get the remainder and quotients of a division. We also use an operation to get the power of a number.

# %%
# The other 3 common arithmetic operations

# Uncomment the code for one of the subsections to see the correct output

# Quotient
# age = 10 // 5 #notice it returns an integer now instead of 2.0 (when using the division operator)

# Remainder
# age = 10 % 5 #gets 0

# Power
# age = 10 ** 5 #gets 100000

print(age)
# Out:
# 2

# %% [markdown]
# Feel free to try out on your own using the space provided below. 🔽

# %% [markdown]
# ## Exercise 1: Create a variable called apples and another called oranges. Assign the value 2 to apple and 3 to orange. After assigning, create a variable called fruits and assign the result of the sum of apple and oranges to it

# %%
#Add code here
