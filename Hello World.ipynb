# %% [markdown]
# <h1>Hello, welcome to your first practical exercise using Python!</h1>
#
# 👋 Before starting, you can simply use " **Ctrl + /** " or remove the symbol " **#** " if you wish to uncomment a line.
#
# 👍 To run a cell, you can use " **Shift + Enter**  or click the " ▶ " symbol on the left of the cell.
#
# <h3>For this session, we will cover the very fundamentals of Python. We will start off by outputting a "Hello World" message.</h3>

# %%
# Outputting the "Hello World" message

# Uncomment the following message to output the "Hello World" message
# print("Hello World") # We use a print function to output the message

# %% [markdown]
# <h1>Congratulations for outputting your first "Hello World" message </h1>
#
# <h3>If you are curious on the application of the print function, the sessions covered later will go more in-depth. </h3>
#
# <h3>The section below shows more ways you can use to print a message. </h3>

# %%
# Uncomment the code below to see how it works

# print("Hello", "World")

# %% [markdown]
# <h3>Did you notice that first print function and second print function returns the same output? This is because by adding a "," between the words "Hello" and "World", it adds a space character between them. If you are still unsure of how the code works, run the cells below to get a better understanding.</h3>

# %%
# Uncomment the code below to see how it works

# print("Hello", "Guys")

# %%
# Uncomment the code below to see how it works

# Before running the code, can you guess the output of the print function?

# print("Hello", 2, "Guys")
# Out:
# Hello 2 Guys

# %% [markdown]
# <h3>Did you guess it right? The "," character in the print function adds a space character regardless of what you put in between the ",". Instead of using space characters to serve as a way to seperate words or numbers, we can use our keyboard "Enter" as well. To replicate "Enter" in our output, we use the character "\n". Refer to the example below to get a better understanding.
# </h3>

# %%
# Uncomment the code below to see how it works

# print("Hello\nWorld") #Note that \n is put between the words "Hello" and "World"

# %%
# If you want to use "," character, do it this way

# Uncomment the code below to see how it works

#the sep argument is what works behind the scene for the "," character, the default is the spacing character but now it is changed to "\n"

# print("Hello","World", sep="\n")
# Out:
# Hello
# World

# %% [markdown]
# <h1>Exercise 1</h1>
# Try outputing a message in the following format:<br>
# Name: [Your Name]<br>
# Course: [Your Course]<br>
# Hobby: [Your Hobby]

# %%
# Uncomment and modify the following line to attempt Exercise 1.
# print("")
